# %% [markdown]
# # *Deep Learning Basics with PyTorch*
# # Part I — Foundations of Machine Learning
# ## Chapter 2: Data, Features, and Representations
#
# In this chapter we use a tiny beginner-friendly flower dataset to see how tabular data becomes a feature matrix `X` and a target vector `y`.
# The focus is on dataset structure, simple visualization, basic preprocessing intuition, and a first train/test workflow.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

np.set_printoptions(precision=2, suppress=True)
plt.style.use('seaborn-v0_8')
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## Loading a Simple Dataset
#
# We will work with a small table of flower measurements. Each row is one example and each column is a feature or a label.

# %%
df = pd.DataFrame({
    "sepal_length_cm": [5.1, 4.9, 5.0, 4.7, 5.4, 5.1, 6.4, 6.0, 6.1, 5.6, 6.7, 6.3],
    "petal_length_cm": [1.4, 1.4, 1.5, 1.3, 1.7, 1.5, 4.5, 4.5, 4.7, 3.9, 4.7, 4.4],
    "petal_width_cm": [0.2, 0.2, 0.2, 0.2, 0.4, 0.3, 1.5, 1.5, 1.4, 1.1, 1.5, 1.3],
    "label": [
        "setosa", "setosa", "setosa", "setosa", "setosa", "setosa",
        "versicolor", "versicolor", "versicolor", "versicolor", "versicolor", "versicolor"
    ]
})

print("dataset shape:", df.shape)
df.head()
# Out:
# dataset shape: (12, 4)
#    sepal_length_cm  petal_length_cm  petal_width_cm   label
# 0              5.1              1.4             0.2  setosa
# 1              4.9              1.4             0.2  setosa
# 2              5.0              1.5             0.2  setosa
# 3              4.7              1.3             0.2  setosa
# 4              5.4              1.7             0.4  setosa

# %% [markdown]
# ## Inspecting Features and Labels
#
# A tabular dataset usually separates input columns (features) from the output column (label).

# %%
feature_names = ["sepal_length_cm", "petal_length_cm", "petal_width_cm"]
label_to_int = {"setosa": 0, "versicolor": 1}

X = df[feature_names].values
y = df["label"].map(label_to_int).values

print("feature names:", feature_names)
print("X shape:", X.shape)
print("y shape:", y.shape)
print("first feature row:", X[0])
print("first label:", y[0])

display(df[feature_names + ["label"]].groupby("label").mean().round(2))
# Out:
# feature names: ['sepal_length_cm', 'petal_length_cm', 'petal_width_cm']
# X shape: (12, 3)
# y shape: (12,)
# first feature row: [5.1 1.4 0.2]
# first label: 0
#             sepal_length_cm  petal_length_cm  petal_width_cm
# label
# setosa                 5.03             1.47            0.25
# versicolor             6.18             4.45            1.38

# %% [markdown]
# ## Simple Visualization
#
# A quick plot helps us see whether the labels look different in feature space before we think about modeling.

# %%
fig, ax = plt.subplots(1, 2, figsize=(9, 3.5))

for label_name, color in [("setosa", "tab:blue"), ("versicolor", "tab:orange")]:
    subset = df[df["label"] == label_name]
    ax[0].scatter(
        subset["petal_length_cm"],
        subset["petal_width_cm"],
        label=label_name,
        color=color,
        s=50,
        alpha=0.8,
    )

ax[0].set_xlabel("petal length (cm)")
ax[0].set_ylabel("petal width (cm)")
ax[0].set_title("Two Features by Label")
ax[0].legend(frameon=False)

label_counts = df["label"].value_counts()
ax[1].bar(label_counts.index, label_counts.values, color=["tab:blue", "tab:orange"])
ax[1].set_title("Label Counts")
ax[1].set_ylabel("count")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Simple Preprocessing Intuition
#
# Features can live on different numeric scales. A common idea is to center each feature around 0 and scale it by its standard deviation.

# %%
feature_means = X.mean(axis=0)
feature_stds = X.std(axis=0)
X_scaled = (X - feature_means) / feature_stds

summary = pd.DataFrame({
    "feature": feature_names,
    "mean": feature_means.round(2),
    "std": feature_stds.round(2),
})

display(summary)
print("first three scaled rows:")
print(X_scaled[:3])
# Out:
#            feature  mean   std
# 0  sepal_length_cm  5.61  0.64
# 1  petal_length_cm  2.96  1.51
# 2   petal_width_cm  0.82  0.58
# first three scaled rows:
# [[-0.79 -1.03 -1.07]
#  [-1.1  -1.03 -1.07]
#  [-0.95 -0.97 -1.07]]

# %% [markdown]
# ## Basic Train/Test Split
#
# To mimic a simple machine learning workflow, we split the dataset into training and testing sets. As a very light baseline, we classify flowers using only a petal-length threshold learned from the training data.

# %%
rng = np.random.default_rng(42)
class0_idx = np.where(y == 0)[0]
class1_idx = np.where(y == 1)[0]
rng.shuffle(class0_idx)
rng.shuffle(class1_idx)

train_idx = np.concatenate([class0_idx[:4], class1_idx[:4]])
test_idx = np.concatenate([class0_idx[4:], class1_idx[4:]])

X_train, X_test = X[train_idx], X[test_idx]
y_train, y_test = y[train_idx], y[test_idx]

petal_idx = feature_names.index("petal_length_cm")
threshold = 0.5 * (
    X_train[y_train == 0, petal_idx].mean() + X_train[y_train == 1, petal_idx].mean()
)
y_pred = (X_test[:, petal_idx] > threshold).astype(int)
accuracy = np.mean(y_pred == y_test)

print("train size:", len(X_train))
print("test size:", len(X_test))
print(f"petal-length threshold: {threshold:.2f} cm")
print(f"baseline accuracy: {accuracy:.2f}")

for features, actual, pred in zip(X_test, y_test, y_pred):
    print(f"features={features} | actual={actual} | predicted={pred}")
# Out:
# train size: 8
# test size: 4
# petal-length threshold: 3.05 cm
# baseline accuracy: 1.00
# features=[4.9 1.4 0.2] | actual=0 | predicted=0
# features=[5.1 1.4 0.2] | actual=0 | predicted=0
# features=[5.6 3.9 1.1] | actual=1 | predicted=1
# features=[6.3 4.4 1.3] | actual=1 | predicted=1

# %% [markdown]
# ## Chapter 2 Summary
#
# - A dataset can be organized as rows of examples and columns of features plus a label.
# - The feature matrix `X` stores the inputs, and the target vector `y` stores the outputs we want to predict.
# - Simple plots help us understand how labels relate to feature values before any serious modeling.
# - Basic preprocessing often means checking scales and standardizing features for easier comparison.
# - A train/test split gives us a simple way to separate learning from evaluation.
